# %% [markdown]
# # Tier-C — Statistical rigour (multi-seed + significance + calibration)
#
# Phase-2 Tier C turns the single-seed Tier-A/B *findings* into statistically defensible *claims*. It
# **reuses the dual-GPU sharded runner** (each shard pinned to one T4 via `CUDA_VISIBLE_DEVICES`) and the
# **per-run S3 resume** (every finished run pushes its CSV + checkpoint, so a session time-out costs at most the
# run in flight — relaunch and it skips everything done).
#
# Three things this notebook adds on top of training:
# 1. **Multi-seed aggregation** — mean ± std and a 95% CI across seeds, per (model, symbol, horizon).
# 2. **Significance tests** — paired tests between model pairs (across the seed×symbol×horizon cells) *and*
#    a per-sample paired bootstrap + McNemar at a representative cell (reloading checkpoints from S3).
# 3. **Probability calibration** — temperature scaling, reporting Expected Calibration Error (ECE) before/after.
#
# Headline pairs we want significance on:
# - **ConvMambaLOB vs MambaLOB-base** (does the Tier-B conv front-end *really* help?)
# - **MambaLOB(all) vs MambaLOB(base40)** (does Tier-A microstructure feature engineering *really* help?)
# - **MambaLOB / ConvMambaLOB vs TLOB** (quantify the gap to the transformer with uncertainty)
#
# Setup: enable **GPU T4 x2**; secrets `GH_PAT`, `AWS_ACCESS_KEY_ID`, `AWS_SECRET_ACCESS_KEY`.
# Clean S3 layout: `experiments/tier_c/{results,checkpoints,figures}/`.

# %% [markdown]
# ## 1. Runtime check (expect 2 GPUs)

# %%
import torch, platform
print("Python:", platform.python_version(), "| Torch:", torch.__version__)
n = torch.cuda.device_count()
print(f"GPUs visible: {n}")
for i in range(n):
    print(f"  cuda:{i} = {torch.cuda.get_device_name(i)}")
assert n >= 1, "Enable GPU. For 2x speedup choose 'GPU T4 x2'."
if n < 2:
    print("Only 1 GPU -> will run a single shard (still works, no speedup).")
# Out:
# Python: 3.12.13 | Torch: 2.10.0+cu128
# GPUs visible: 2
#   cuda:0 = Tesla T4
#   cuda:1 = Tesla T4

# %% [markdown]
# ## 2. Get the project code (GH_PAT secret)

# %%
import sys, subprocess, pathlib
REPO_URL = "https://github.com/rajjoseph48/nse-lob-capstone.git"
REPO_DIR = "nse-lob-capstone"
def _get_secret(name):
    try:
        from kaggle_secrets import UserSecretsClient
        v = UserSecretsClient().get_secret(name)
        if v:
            return v
    except Exception:
        pass
    try:
        from google.colab import userdata
        v = userdata.get(name)
        if v:
            return v
    except Exception:
        pass
    import os
    return os.environ.get(name, "")
GITHUB_TOKEN = _get_secret("GH_PAT")
def add_modeling(base):
    base = pathlib.Path(base)
    for cand in (base / "modeling", base):
        if (cand / "models.py").exists():
            sys.path.insert(0, str(cand.resolve()))
            return str(cand.resolve())
    return None
MODELING_DIR = None
for c in (".", REPO_DIR, "/kaggle/working/" + REPO_DIR, "/content/" + REPO_DIR):
    MODELING_DIR = add_modeling(c)
    if MODELING_DIR:
        break
if not MODELING_DIR:
    url = REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@") if GITHUB_TOKEN else REPO_URL
    subprocess.run(["git", "clone", "--depth", "1", url], check=True)
    MODELING_DIR = add_modeling(REPO_DIR)
print("modeling/ dir:", MODELING_DIR)
# Out:
# modeling/ dir: /kaggle/working/nse-lob-capstone/modeling

# %% [markdown]
# ## 3. Install deps (Mamba kernel + boto3 + scipy for the tests)

# %%
import subprocess, sys
def pipq(*pkgs): subprocess.run([sys.executable, "-m", "pip", "install", "-q", *pkgs], check=False)
pipq("boto3", "scipy")
pipq("ninja", "packaging", "setuptools", "wheel")
pipq("--no-build-isolation", "causal-conv1d")
pipq("--no-build-isolation", "mamba-ssm")
try:
    import mamba_ssm
    print("install step done | mamba-ssm", mamba_ssm.__version__)
except Exception as e:
    print("install step done | mamba-ssm NOT importable -> pure-PyTorch fallback:", repr(e))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 91.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 32.0 MB/s eta 0:00:00
# install step done | mamba-ssm 2.3.2.post1

# %% [markdown]
# ## 4. Download NSE data from S3 (shared by both shards)

# %%
import os, boto3, pathlib
os.environ["AWS_ACCESS_KEY_ID"] = _get_secret("AWS_ACCESS_KEY_ID")
os.environ["AWS_SECRET_ACCESS_KEY"] = _get_secret("AWS_SECRET_ACCESS_KEY")
BUCKET, PREFIX, REGION = "lob-capstone-data", "lob-data/dhan/", "ap-south-2"
DATA_DIR_NSE = "nse_data/dhan"; pathlib.Path(DATA_DIR_NSE).mkdir(parents=True, exist_ok=True)
s3 = boto3.client("s3", region_name=REGION)
n = 0
for o in s3.list_objects_v2(Bucket=BUCKET, Prefix=PREFIX).get("Contents", []):
    if o["Size"] == 0:
        continue
    dst = os.path.join(DATA_DIR_NSE, o["Key"].split("/")[-1])
    if not os.path.exists(dst):
        s3.download_file(BUCKET, o["Key"], dst)
    n += 1
print(f"{n} parquet files in {DATA_DIR_NSE}")
# Out:
# 27 parquet files in nse_data/dhan

# %% [markdown]
# ## 5. Build the multi-seed run-list + resume
# We multi-seed only the **headline configurations** (running every model x feature x seed would be wasteful).
# `SEEDS` is the knob — default 3 seeds; bump to 5 for tighter CIs. Note **TLOB dominates runtime** (~1 h/run vs
# minutes for Mamba), so the grid below is ~3-6 h on 2xT4 across one or two sessions; resume makes that safe.

# %%
import json, pathlib, pandas as pd
from nbenv import s3_client, s3_pull_area

AREA = "tier_c"
MERGED = pathlib.Path("results/tier_c.csv")
SEEDS = [0, 1, 2]                                    # bump to [0,1,2,3,4] for 5-seed CIs

# Headline configs: (model, feature_set). 'all' = best from Tier A.
CONFIGS = [
    ("mambalob",     "base40"),                      # Tier-A reference (raw LOB)
    ("mambalob",     "all"),                         # Tier-A treatment (+microstructure)
    ("convmambalob", "all"),                         # Tier-B best variant
    ("tlob",         "all"),                         # transformer SOTA target
]
SYMBOLS = ["NIFTY", "BANKNIFTY"]
HORIZONS = [10, 100]

GRID = []
for (model, fs) in CONFIGS:
    for sym in SYMBOLS:
        for h in HORIZONS:
            for sd in SEEDS:
                GRID.append({"model": model, "symbol": sym, "feature_set": fs,
                             "horizon": h, "label_scheme": "A", "seed": sd})

# Resume: pull merged + each shard CSV; skip anything already done (per-run granularity).
_s3 = s3_client(); pathlib.Path("results").mkdir(exist_ok=True)
s3_pull_area(_s3, MERGED, AREA)
shard_csvs = [pathlib.Path(f"results/shard{i}.csv") for i in range(2)]
for sc in shard_csvs:
    s3_pull_area(_s3, sc, AREA)
done = set()
for f in [MERGED, *shard_csvs]:
    if f.exists():
        d = pd.read_csv(f)
        done |= {(r.model, r.symbol, r.feature_set, int(r.horizon), r.label_scheme, int(r.seed))
                 for r in d.itertuples()}
def _key(s):
    return (s["model"], s["symbol"], s["feature_set"], int(s["horizon"]), s["label_scheme"], int(s["seed"]))
todo = [s for s in GRID if _key(s) not in done]
pathlib.Path("runlist.json").write_text(json.dumps(todo))
print(f"grid={len(GRID)} | done={len(done)} | to run this session={len(todo)}")
print(f"(TLOB runs in to-do: {sum(1 for s in todo if s['model']=='tlob')} -- these are the slow ones)")
todo[:8]
# Out:
#    pulled s3://lob-capstone-data/experiments/tier_c/results/shard0.csv (resuming)
#    pulled s3://lob-capstone-data/experiments/tier_c/results/shard1.csv (resuming)
# grid=48 | done=28 | to run this session=20
# (TLOB runs in to-do: 12 -- these are the slow ones)
# [{'model': 'convmambalob',
#   'symbol': 'NIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 1},
#  {'model': 'convmambalob',
#   'symbol': 'NIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 2},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 1},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 2},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 1},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 2}]

# %% [markdown]
# ## 6. Launch one shard per GPU (concurrent) and stream logs
# Each shard is a subprocess pinned to one GPU, run with `-u`/`PYTHONUNBUFFERED` so logs stream live.

# %%
import os, sys, subprocess, time, torch

n_gpus = torch.cuda.device_count()
nshards = max(1, n_gpus)
RUN_SHARD = f"{MODELING_DIR}/run_shard.py"
pathlib.Path("results").mkdir(exist_ok=True)

procs = []
for i in range(nshards):
    env = dict(os.environ); env["CUDA_VISIBLE_DEVICES"] = str(i)
    env["PYTHONUNBUFFERED"] = "1"
    logf = f"shard{i}.log"; fh = open(logf, "w")
    cmd = [sys.executable, "-u", RUN_SHARD, "--runlist", "runlist.json", "--shard", str(i),
           "--nshards", str(nshards), "--data-dir", DATA_DIR_NSE, "--out", f"results/shard{i}.csv",
           "--ckpt-dir", "checkpoints/tierc", "--area", "tier_c", "--epochs", "20"]
    procs.append([subprocess.Popen(cmd, env=env, stdout=fh, stderr=subprocess.STDOUT), fh, logf, 0])
    print(f"launched shard {i} on CUDA_VISIBLE_DEVICES={i}")

while any(p[0].poll() is None for p in procs):
    for p in procs:
        with open(p[2]) as r:
            r.seek(p[3]); chunk = r.read(); p[3] = r.tell()
        if chunk:
            print(chunk, end="")
    time.sleep(10)
for p in procs:                                        # final flush
    p[1].close()
    with open(p[2]) as r:
        r.seek(p[3]); print(r.read(), end="")
print("\nexit codes:", [p[0].poll() for p in procs])
# Out:
# launched shard 0 on CUDA_VISIBLE_DEVICES=0
# launched shard 1 on CUDA_VISIBLE_DEVICES=1
# Using device: cuda
# [shard 0/2] device=cuda | CUDA_VISIBLE_DEVICES=0 | 10 runs
#
# [shard 0] run 1/10: {'model': 'convmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   convmambalob_NIFTY_all_h100_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
# Using device: cuda
# [shard 1/2] device=cuda | CUDA_VISIBLE_DEVICES=1 | 10 runs
#
# [shard 1] run 1/10: {'model': 'convmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   convmambalob_NIFTY_all_h100_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 0.9694 | val_loss 0.9644 | val_f1 0.6213 ← best
#   epoch   1 | train_loss 0.9860 | val_loss 0.9390 | val_f1 0.6441 ← best
#   epoch   5 | train_loss 0.4488 | val_loss 1.9392 | val_f1 0.5594
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_NIFTY_all_h100_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_NIFTY_all_h100_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6167 mF1=0.4645 (F=66, 1738s)
#
# [shard 1] run 2/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h10_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   5 | train_loss 0.5096 | val_loss 1.8081 | val_f1 0.5974
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_NIFTY_all_h100_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_NIFTY_all_h100_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6250 mF1=0.4758 (F=66, 1864s)
#
# [shard 0] run 2/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 23.9960 | val_loss 0.8726 | val_f1 0.6144 ← best
#   epoch   1 | train_loss 1835532.2609 | val_loss 0.8717 | val_f1 0.6152 ← best
#   epoch   5 | train_loss 4.4372 | val_loss 0.9011 | val_f1 0.6046
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h10_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h10_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6103 mF1=0.6067 (F=66, 1718s)
#
# [shard 1] run 3/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   5 | train_loss 31.2086 | val_loss 1.5992 | val_f1 0.6099
#   epoch   1 | train_loss 26914.8206 | val_loss 0.9275 | val_f1 0.6424 ← best
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h10_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6169 mF1=0.6111 (F=66, 2250s)
#
# [shard 0] run 3/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h10_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 1.2887 | val_loss 0.8682 | val_f1 0.6173 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h100_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.5876 mF1=0.4392 (F=66, 1380s)
#
# [shard 1] run 4/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h100_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 134.9539 | val_loss 0.9659 | val_f1 0.6274 ← best
#   epoch   5 | train_loss 1.0420 | val_loss 0.9178 | val_f1 0.6053
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h100_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h100_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6053 mF1=0.4524 (F=66, 1368s)
#
# [shard 1] run 5/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   tlob_NIFTY_all_h10_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h10_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h10_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6102 mF1=0.6065 (F=66, 2250s)
#
# [shard 0] run 4/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h100_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 172.7190 | val_loss 1.0136 | val_f1 0.5935 ← best
#   epoch   1 | train_loss 0.9203 | val_loss 0.8859 | val_f1 0.6121 ← best
#   epoch   5 | train_loss 30101902.7232 | val_loss 2.1508 | val_f1 0.5840
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/convmambalob_BANKNIFTY_all_h100_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/convmambalob_BANKNIFTY_all_h100_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6244 mF1=0.4611 (F=66, 1872s)
#
# [shard 0] run 5/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
#   epoch   1 | train_loss 0.9186 | val_loss 0.8890 | val_f1 0.6130 ← best
#   epoch   5 | train_loss 0.8464 | val_loss 0.8714 | val_f1 0.6203
#   Early stop at epoch 7 (best epoch 4).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h10_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h10_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6069 mF1=0.5837 (F=66, 4115s)
#
# [shard 1] run 6/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
#   epoch   1 | train_loss 0.8824 | val_loss 0.8711 | val_f1 0.6798 ← best
#   epoch   5 | train_loss 0.8487 | val_loss 0.8736 | val_f1 0.6236 ← best
#   Early stop at epoch 8 (best epoch 5).
#   epoch   5 | train_loss 0.6295 | val_loss 1.0854 | val_f1 0.6968
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h10_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6052 mF1=0.5845 (F=66, 5046s)
#
# [shard 0] run 6/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   tlob_NIFTY_all_h10_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h100_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.7138 mF1=0.5375 (F=66, 2945s)
#
# [shard 1] run 7/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   tlob_NIFTY_all_h100_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
#   epoch   1 | train_loss 0.9216 | val_loss 0.8942 | val_f1 0.5916 ← best
#   epoch   1 | train_loss 0.8816 | val_loss 0.8625 | val_f1 0.7187 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h100_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h100_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6982 mF1=0.5334 (F=66, 2352s)
#
# [shard 1] run 8/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   tlob_BANKNIFTY_all_h10_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
#   epoch   1 | train_loss 0.8475 | val_loss 0.8324 | val_f1 0.6423 ← best
#   epoch   5 | train_loss 0.8472 | val_loss 0.8754 | val_f1 0.6224
#   Early stop at epoch 7 (best epoch 4).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h10_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h10_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6067 mF1=0.5845 (F=66, 4415s)
#
# [shard 0] run 7/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   tlob_NIFTY_all_h100_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
#   epoch   1 | train_loss 0.8818 | val_loss 0.8524 | val_f1 0.7280 ← best
#   epoch   5 | train_loss 0.7346 | val_loss 0.8640 | val_f1 0.6368
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h10_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h10_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.6343 mF1=0.6289 (F=66, 3520s)
#
# [shard 1] run 9/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
#   epoch   1 | train_loss 0.8767 | val_loss 0.8788 | val_f1 0.6994 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_NIFTY_all_h100_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_NIFTY_all_h100_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.7189 mF1=0.5485 (F=66, 2519s)
#
# [shard 0] run 8/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
#   epoch   1 | train_loss 0.8453 | val_loss 0.8349 | val_f1 0.6415 ← best
#   epoch   5 | train_loss 0.5621 | val_loss 1.1846 | val_f1 0.7185
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h100_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.7121 mF1=0.5315 (F=66, 2936s)
#
# [shard 1] run 10/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   tlob_BANKNIFTY_all_h100_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
#   epoch   1 | train_loss 0.8741 | val_loss 0.8857 | val_f1 0.6921 ← best
#   epoch   5 | train_loss 0.7430 | val_loss 0.8556 | val_f1 0.6392
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h10_s0_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6319 mF1=0.6264 (F=66, 3771s)
#
# [shard 0] run 9/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 2}
# ============================================================================
#   tlob_BANKNIFTY_all_h10_s2  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
#   epoch   1 | train_loss 0.8464 | val_loss 0.8523 | val_f1 0.6255 ← best
#   epoch   5 | train_loss 0.5417 | val_loss 1.2095 | val_f1 0.7033
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h100_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h100_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard1.csv
#   -> wF1=0.7096 mF1=0.5279 (F=66, 2926s)
# [shard 1] done.
#   epoch   5 | train_loss 0.7376 | val_loss 0.8578 | val_f1 0.6364
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h10_s2.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h10_s2_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.6422 mF1=0.6353 (F=66, 3143s)
#
# [shard 0] run 10/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 1}
# ============================================================================
#   tlob_BANKNIFTY_all_h100_s1  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
#   epoch   1 | train_loss 0.8733 | val_loss 0.8970 | val_f1 0.6601 ← best
#   epoch   5 | train_loss 0.5524 | val_loss 1.2548 | val_f1 0.7036
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/tier_c/checkpoints/tlob_BANKNIFTY_all_h100_s1.pt
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tlob_BANKNIFTY_all_h100_s1_metrics.json
#    ^ s3://lob-capstone-data/experiments/tier_c/results/shard0.csv
#   -> wF1=0.7211 mF1=0.5260 (F=66, 3763s)
# [shard 0] done.
#
# exit codes: [0, 0]

# %% [markdown]
# ## 7. Merge shard CSVs + push to S3

# %%
import glob, pandas as pd
from nbenv import s3_client, s3_put_area
keys = ["model", "symbol", "feature_set", "horizon", "label_scheme", "seed"]
frames = [pd.read_csv(MERGED)] if MERGED.exists() else []
frames += [pd.read_csv(f) for f in glob.glob("results/shard*.csv")]
alldf = pd.concat(frames, ignore_index=True).drop_duplicates(subset=keys, keep="last") if frames else pd.DataFrame()
alldf.to_csv(MERGED, index=False)
s3_put_area(s3_client(), MERGED, AREA)
print(f"merged {len(alldf)} rows -> {MERGED}  (s3: experiments/{AREA}/results/)")
alldf.sort_values(keys)
# Out:
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tier_c.csv
# merged 48 rows -> results/tier_c.csv  (s3: experiments/tier_c/results/)
#            model     symbol feature_set label_scheme  horizon  seed  \
# 39  convmambalob  BANKNIFTY         all            A       10     0
# 15  convmambalob  BANKNIFTY         all            A       10     1
# 40  convmambalob  BANKNIFTY         all            A       10     2
# 16  convmambalob  BANKNIFTY         all            A      100     0
# 41  convmambalob  BANKNIFTY         all            A      100     1
# 17  convmambalob  BANKNIFTY         all            A      100     2
# 36  convmambalob      NIFTY         all            A       10     0
# 12  convmambalob      NIFTY         all            A       10     1
# 37  convmambalob      NIFTY         all            A       10     2
# 13  convmambalob      NIFTY         all            A      100     0
# 38  convmambalob      NIFTY         all            A      100     1
# 14  convmambalob      NIFTY         all            A      100     2
# 33      mambalob  BANKNIFTY         all            A       10     0
# 9       mambalob  BANKNIFTY         all            A       10     1
# 34      mambalob  BANKNIFTY         all            A       10     2
# 10      mambalob  BANKNIFTY         all            A      100     0
# 35      mambalob  BANKNIFTY         all            A      100     1
# 11      mambalob  BANKNIFTY         all            A      100     2
# 27      mambalob  BANKNIFTY      base40            A       10     0
# 3       mambalob  BANKNIFTY      base40            A       10     1
# 28      mambalob  BANKNIFTY      base40            A       10     2
# 4       mambalob  BANKNIFTY      base40            A      100     0
# 29      mambalob  BANKNIFTY      base40            A      100     1
# 5       mambalob  BANKNIFTY      base40            A      100     2
# 30      mambalob      NIFTY         all            A       10     0
# 6       mambalob      NIFTY         all            A       10     1
# 31      mambalob      NIFTY         all            A       10     2
# 7       mambalob      NIFTY         all            A      100     0
# 32      mambalob      NIFTY         all            A      100     1
# 8       mambalob      NIFTY         all            A      100     2
# 24      mambalob      NIFTY      base40            A       10     0
# 0       mambalob      NIFTY      base40            A       10     1
# 25      mambalob      NIFTY      base40            A       10     2
# 1       mambalob      NIFTY      base40            A      100     0
# 26      mambalob      NIFTY      base40            A      100     1
# 2       mambalob      NIFTY      base40            A      100     2
# 45          tlob  BANKNIFTY         all            A       10     0
# 21          tlob  BANKNIFTY         all            A       10     1
# 46          tlob  BANKNIFTY         all            A       10     2
# 22          tlob  BANKNIFTY         all            A      100     0
# 47          tlob  BANKNIFTY         all            A      100     1
# 23          tlob  BANKNIFTY         all            A      100     2
# 42          tlob      NIFTY         all            A       10     0
# 18          tlob      NIFTY         all            A       10     1
# 43          tlob      NIFTY         all            A       10     2
# 19          tlob      NIFTY         all            A      100     0
# 44          tlob      NIFTY         all            A      100     1
# 20          tlob      NIFTY         all            A      100     2
#
#        strategy  n_features  n_params  best_epoch  ...  test_macro_f1  \
# 39  weighted_ce          66    143735           3  ...         0.6111
# 15  weighted_ce          66    143735           2  ...         0.6067
# 40  weighted_ce          66    143735           3  ...         0.6065
# 16  weighted_ce          66    143735           1  ...         0.4392
# 41  weighted_ce          66    143735           2  ...         0.4611
# 17  weighted_ce          66    143735           1  ...         0.4524
# 36  weighted_ce          66    143735           3  ...         0.5254
# 12  weighted_ce          66    143735           3  ...         0.5219
# 37  weighted_ce          66    143735           2  ...         0.5264
# 13  weighted_ce          66    143735           1  ...         0.4829
# 38  weighted_ce          66    143735           2  ...         0.4758
# 14  weighted_ce          66    143735           2  ...         0.4645
# 33  weighted_ce          66     69955           7  ...         0.6016
# 9   weighted_ce          66     69955           7  ...         0.6077
# 34  weighted_ce          66     69955           7  ...         0.6037
# 10  weighted_ce          66     69955           4  ...         0.4509
# 35  weighted_ce          66     69955           5  ...         0.4374
# 11  weighted_ce          66     69955           4  ...         0.4498
# 27  weighted_ce          40     68291           5  ...         0.4488
# 3   weighted_ce          40     68291           5  ...         0.4379
# 28  weighted_ce          40     68291           6  ...         0.4434
# 4   weighted_ce          40     68291           6  ...         0.3469
# 29  weighted_ce          40     68291           8  ...         0.3421
# 5   weighted_ce          40     68291          11  ...         0.3627
# 30  weighted_ce          66     69955           7  ...         0.5204
# 6   weighted_ce          66     69955           4  ...         0.5092
# 31  weighted_ce          66     69955           6  ...         0.5083
# 7   weighted_ce          66     69955           2  ...         0.4731
# 32  weighted_ce          66     69955           1  ...         0.4482
# 8   weighted_ce          66     69955           5  ...         0.4602
# 24  weighted_ce          40     68291          20  ...         0.5114
# 0   weighted_ce          40     68291          18  ...         0.5008
# 25  weighted_ce          40     68291          19  ...         0.5246
# 1   weighted_ce          40     68291           6  ...         0.4343
# 26  weighted_ce          40     68291          14  ...         0.4284
# 2   weighted_ce          40     68291          12  ...         0.4387
# 45  weighted_ce          66   1803728           3  ...         0.6264
# 21  weighted_ce          66   1803728           3  ...         0.6289
# 46  weighted_ce          66   1803728           2  ...         0.6353
# 22  weighted_ce          66   1803728           2  ...         0.5315
# 47  weighted_ce          66   1803728           3  ...         0.5260
# 23  weighted_ce          66   1803728           2  ...         0.5279
# 42  weighted_ce          66   1803728           5  ...         0.5845
# 18  weighted_ce          66   1803728           4  ...         0.5837
# 43  weighted_ce          66   1803728           4  ...         0.5845
# 19  weighted_ce          66   1803728           2  ...         0.5375
# 44  weighted_ce          66   1803728           1  ...         0.5485
# 20  weighted_ce          66   1803728           1  ...         0.5334
#
#     test_weighted_f1  test_mcc  recall_down  recall_stat  recall_up  \
# 39            0.6169    0.4209       0.5924       0.5944     0.6523
# 15            0.6103    0.4221       0.5678       0.7027     0.5777
# 40            0.6102    0.4230       0.5378       0.7080     0.6026
# 16            0.5876    0.3066       0.4851       0.4974     0.5334
# 41            0.6244    0.3222       0.6487       0.2548     0.5476
# 17            0.6053    0.3247       0.5564       0.4724     0.5120
# 36            0.5440    0.3032       0.6224       0.4145     0.5418
# 12            0.5404    0.2980       0.5325       0.4111     0.6249
# 37            0.5468    0.3060       0.6107       0.3834     0.5852
# 13            0.6425    0.3525       0.6122       0.1523     0.6966
# 38            0.6250    0.3273       0.6343       0.2327     0.6015
# 14            0.6167    0.3163       0.5401       0.1856     0.6932
# 33            0.6068    0.4079       0.6206       0.6102     0.5858
# 9             0.6121    0.4180       0.5997       0.6483     0.5920
# 34            0.6082    0.4119       0.6328       0.6272     0.5666
# 10            0.6126    0.2920       0.6547       0.1681     0.5629
# 35            0.5952    0.2872       0.7648       0.1368     0.4524
# 11            0.6096    0.2882       0.6788       0.1590     0.5442
# 27            0.4511    0.1807       0.4987       0.4824     0.3837
# 3             0.4399    0.1684       0.5469       0.4498     0.3404
# 28            0.4483    0.1737       0.5835       0.3778     0.3808
# 4             0.4671    0.0869       0.4052       0.2579     0.4619
# 29            0.4598    0.0792       0.4200       0.2669     0.4289
# 5             0.4957    0.0921       0.4534       0.1284     0.5271
# 30            0.5413    0.2977       0.5794       0.3696     0.6121
# 6             0.5334    0.2882       0.5900       0.3069     0.6338
# 31            0.5339    0.2927       0.5758       0.2835     0.6728
# 7             0.6271    0.3332       0.5500       0.1650     0.7258
# 32            0.6179    0.3172       0.5728       0.0294     0.7577
# 8             0.6175    0.3107       0.5728       0.1163     0.6971
# 24            0.5339    0.2858       0.5670       0.3932     0.5725
# 0             0.5265    0.2766       0.6317       0.3109     0.5624
# 25            0.5421    0.3068       0.5877       0.5016     0.4957
# 1             0.5845    0.2684       0.4732       0.1134     0.7306
# 26            0.5724    0.2638       0.4198       0.1570     0.7422
# 2             0.5851    0.2640       0.5050       0.1605     0.6697
# 45            0.6319    0.4561       0.5852       0.7304     0.5921
# 21            0.6343    0.4587       0.6033       0.7249     0.5860
# 46            0.6422    0.4610       0.6207       0.6505     0.6471
# 22            0.7121    0.4590       0.7006       0.2714     0.6962
# 47            0.7211    0.4795       0.7390       0.0919     0.7492
# 23            0.7096    0.4566       0.7353       0.2606     0.6573
# 42            0.6052    0.3958       0.6602       0.4975     0.6006
# 18            0.6069    0.3974       0.6760       0.4390     0.6365
# 43            0.6067    0.3967       0.6413       0.4573     0.6560
# 19            0.7138    0.4764       0.7656       0.1489     0.7067
# 44            0.7189    0.4820       0.7156       0.2232     0.7379
# 20            0.6982    0.4556       0.6017       0.2692     0.7847
#
#     baseline_majority_wf1  baseline_stat_wf1  baseline_random_wf1  \
# 39                 0.1872             0.1107               0.3409
# 15                 0.1872             0.1107               0.3409
# 40                 0.1872             0.1107               0.3409
# 16                 0.3022             0.0031               0.4630
# 41                 0.3022             0.0031               0.4630
# 17                 0.3022             0.0031               0.4630
# 36                 0.2091             0.0912               0.3493
# 12                 0.2091             0.0912               0.3493
# 37                 0.2091             0.0912               0.3493
# 13                 0.3017             0.0057               0.4507
# 38                 0.3017             0.0057               0.4507
# 14                 0.3017             0.0057               0.4507
# 33                 0.1872             0.1107               0.3409
# 9                  0.1872             0.1107               0.3409
# 34                 0.1872             0.1107               0.3409
# 10                 0.3022             0.0031               0.4630
# 35                 0.3022             0.0031               0.4630
# 11                 0.3022             0.0031               0.4630
# 27                 0.1872             0.1107               0.3409
# 3                  0.1872             0.1107               0.3409
# 28                 0.1872             0.1107               0.3409
# 4                  0.3022             0.0031               0.4630
# 29                 0.3022             0.0031               0.4630
# 5                  0.3022             0.0031               0.4630
# 30                 0.2091             0.0912               0.3493
# 6                  0.2091             0.0912               0.3493
# 31                 0.2091             0.0912               0.3493
# 7                  0.3017             0.0057               0.4507
# 32                 0.3017             0.0057               0.4507
# 8                  0.3017             0.0057               0.4507
# 24                 0.2091             0.0912               0.3493
# 0                  0.2091             0.0912               0.3493
# 25                 0.2091             0.0912               0.3493
# 1                  0.3017             0.0057               0.4507
# 26                 0.3017             0.0057               0.4507
# 2                  0.3017             0.0057               0.4507
# 45                 0.1872             0.1107               0.3409
# 21                 0.1872             0.1107               0.3409
# 46                 0.1872             0.1107               0.3409
# 22                 0.3022             0.0031               0.4630
# 47                 0.3022             0.0031               0.4630
# 23                 0.3022             0.0031               0.4630
# 42                 0.2091             0.0912               0.3493
# 18                 0.2091             0.0912               0.3493
# 43                 0.2091             0.0912               0.3493
# 19                 0.3017             0.0057               0.4507
# 44                 0.3017             0.0057               0.4507
# 20                 0.3017             0.0057               0.4507
#
#     train_time_s
# 39        2249.8
# 15        1717.5
# 40        2250.4
# 16        1380.4
# 41        1872.0
# 17        1368.2
# 36        2059.7
# 12        2263.8
# 37        1712.8
# 13        1506.9
# 38        1864.4
# 14        1737.8
# 33         725.7
# 9          769.7
# 34         732.2
# 10         536.8
# 35         571.1
# 11         533.8
# 27         561.0
# 3          598.1
# 28         636.2
# 4          674.4
# 29         774.4
# 5         1048.4
# 30         735.2
# 6          538.7
# 31         656.1
# 7          381.9
# 32         287.4
# 8          615.4
# 24        1410.4
# 0         1502.2
# 25        1421.0
# 1          674.7
# 26        1205.9
# 2         1126.4
# 45        3771.0
# 21        3520.1
# 46        3143.1
# 22        2935.9
# 47        3763.4
# 23        2926.1
# 42        5045.9
# 18        4115.5
# 43        4415.0
# 19        2944.6
# 44        2518.9
# 20        2352.1
#
# [48 rows x 23 columns]

# %% [markdown]
# ## 8. Multi-seed aggregation — mean ± std and 95% CI across seeds
# For each (model, feature_set, symbol, horizon) we summarise weighted/macro-$F_1$ over seeds. The 95% CI is a
# Student-t interval on the seed mean (small-$n$ honest)..

# %%
import numpy as np, pandas as pd
from scipy import stats as ss
res = pd.read_csv(MERGED)

def cfg_label(r): return f"{r.model}/{r.feature_set}"

def agg(metric):
    rows = []
    g = res.groupby(["model", "feature_set", "symbol", "horizon"])[metric]
    for (model, fs, sym, h), s in g:
        v = s.values.astype(float); n = len(v)
        mean = v.mean(); sd = v.std(ddof=1) if n > 1 else 0.0
        if n > 1:
            lo, hi = ss.t.interval(0.95, n - 1, loc=mean, scale=sd / np.sqrt(n))
        else:
            lo = hi = mean
        rows.append({"config": f"{model}/{fs}", "symbol": sym, "horizon": h, "n": n,
                     "mean": round(mean, 4), "std": round(sd, 4),
                     "ci95": f"[{lo:.4f}, {hi:.4f}]"})
    return pd.DataFrame(rows).sort_values(["symbol", "horizon", "config"])

print("=== weighted-F1 (mean +/- std, 95% CI over seeds) ===")
wf = agg("test_weighted_f1"); print(wf.to_string(index=False))
print("\n=== macro-F1 ===")
mf = agg("test_macro_f1"); print(mf.to_string(index=False))

# persist the summary
wf.to_csv("results/tier_c_summary_wf1.csv", index=False)
mf.to_csv("results/tier_c_summary_mf1.csv", index=False)
from nbenv import s3_client, s3_put_area
s3_put_area(s3_client(), "results/tier_c_summary_wf1.csv", AREA)
s3_put_area(s3_client(), "results/tier_c_summary_mf1.csv", AREA)
# Out:
# === weighted-F1 (mean +/- std, 95% CI over seeds) ===
#           config    symbol  horizon  n   mean    std             ci95
# convmambalob/all BANKNIFTY       10  3 0.6125 0.0038 [0.6029, 0.6220]
#     mambalob/all BANKNIFTY       10  3 0.6090 0.0027 [0.6022, 0.6159]
#  mambalob/base40 BANKNIFTY       10  3 0.4464 0.0058 [0.4320, 0.4609]
#         tlob/all BANKNIFTY       10  3 0.6361 0.0054 [0.6227, 0.6495]
# convmambalob/all BANKNIFTY      100  3 0.6058 0.0184 [0.5600, 0.6515]
#     mambalob/all BANKNIFTY      100  3 0.6058 0.0093 [0.5827, 0.6289]
#  mambalob/base40 BANKNIFTY      100  3 0.4742 0.0190 [0.4271, 0.5213]
#         tlob/all BANKNIFTY      100  3 0.7143 0.0060 [0.6992, 0.7293]
# convmambalob/all     NIFTY       10  3 0.5437 0.0032 [0.5358, 0.5517]
#     mambalob/all     NIFTY       10  3 0.5362 0.0044 [0.5252, 0.5472]
#  mambalob/base40     NIFTY       10  3 0.5342 0.0078 [0.5148, 0.5536]
#         tlob/all     NIFTY       10  3 0.6063 0.0009 [0.6040, 0.6086]
# convmambalob/all     NIFTY      100  3 0.6281 0.0132 [0.5953, 0.6608]
#     mambalob/all     NIFTY      100  3 0.6208 0.0054 [0.6073, 0.6343]
#  mambalob/base40     NIFTY      100  3 0.5807 0.0072 [0.5629, 0.5985]
#         tlob/all     NIFTY      100  3 0.7103 0.0108 [0.6835, 0.7371]
#
# === macro-F1 ===
#           config    symbol  horizon  n   mean    std             ci95
# convmambalob/all BANKNIFTY       10  3 0.6081 0.0026 [0.6016, 0.6146]
#     mambalob/all BANKNIFTY       10  3 0.6043 0.0031 [0.5966, 0.6120]
#  mambalob/base40 BANKNIFTY       10  3 0.4434 0.0055 [0.4298, 0.4569]
#         tlob/all BANKNIFTY       10  3 0.6302 0.0046 [0.6188, 0.6416]
# convmambalob/all BANKNIFTY      100  3 0.4509 0.0110 [0.4235, 0.4783]
#     mambalob/all BANKNIFTY      100  3 0.4460 0.0075 [0.4274, 0.4647]
#  mambalob/base40 BANKNIFTY      100  3 0.3506 0.0108 [0.3238, 0.3773]
#         tlob/all BANKNIFTY      100  3 0.5285 0.0028 [0.5215, 0.5354]
# convmambalob/all     NIFTY       10  3 0.5246 0.0024 [0.5187, 0.5304]
#     mambalob/all     NIFTY       10  3 0.5126 0.0067 [0.4959, 0.5294]
#  mambalob/base40     NIFTY       10  3 0.5123 0.0119 [0.4826, 0.5419]
#         tlob/all     NIFTY       10  3 0.5842 0.0005 [0.5831, 0.5854]
# convmambalob/all     NIFTY      100  3 0.4744 0.0093 [0.4513, 0.4975]
#     mambalob/all     NIFTY      100  3 0.4605 0.0125 [0.4296, 0.4914]
#  mambalob/base40     NIFTY      100  3 0.4338 0.0052 [0.4210, 0.4466]
#         tlob/all     NIFTY      100  3 0.5398 0.0078 [0.5204, 0.5592]
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tier_c_summary_wf1.csv
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tier_c_summary_mf1.csv

# %% [markdown]
# ## 9. Significance tests across seeds (paired)
# For each model pair we pair observations by (seed, symbol, horizon) and run a paired t-test + Wilcoxon
# signed-rank on the weighted-$F_1$ difference. This answers "is A reliably better than B across the board?"
# with the seeds as repeated measures. (Small $n$ -> we report the mean Δ, both p-values, and win-rate.)

# %%
import numpy as np, pandas as pd
from scipy import stats as ss
res = pd.read_csv(MERGED)

def series(model, fs):
    s = res[(res.model == model) & (res.feature_set == fs)]
    return s.set_index(["seed", "symbol", "horizon"])["test_weighted_f1"]

PAIRS = [
    ("ConvMamba vs Mamba (Tier-B)",       ("convmambalob", "all"),   ("mambalob", "all")),
    ("Mamba all vs base40 (Tier-A)",      ("mambalob", "all"),       ("mambalob", "base40")),
    ("Mamba vs TLOB",                     ("mambalob", "all"),       ("tlob", "all")),
    ("ConvMamba vs TLOB",                 ("convmambalob", "all"),   ("tlob", "all")),
]
out = []
for name, (ma, fa), (mb, fb) in PAIRS:
    a, b = series(ma, fa), series(mb, fb)
    idx = a.index.intersection(b.index)
    da, db = a.loc[idx].values, b.loc[idx].values
    diff = da - db
    if len(diff) < 2:
        out.append({"comparison": name, "n_pairs": len(diff), "mean_delta": np.nan}); continue
    t_p = ss.ttest_rel(da, db).pvalue
    try:
        w_p = ss.wilcoxon(da, db).pvalue
    except ValueError:
        w_p = np.nan
    out.append({"comparison": name, "n_pairs": len(diff),
                "mean_delta_wF1": round(float(diff.mean()), 4),
                "wins_A": int((diff > 0).sum()),
                "ttest_p": round(float(t_p), 4),
                "wilcoxon_p": round(float(w_p), 4) if w_p == w_p else None})
sig = pd.DataFrame(out)
print(sig.to_string(index=False))
print("\n(positive mean_delta => first model better; p<0.05 => difference unlikely by chance)")
sig.to_csv("results/tier_c_significance.csv", index=False)
from nbenv import s3_client, s3_put_area
s3_put_area(s3_client(), "results/tier_c_significance.csv", AREA)
# Out:
#                   comparison  n_pairs  mean_delta_wF1  wins_A  ttest_p  wilcoxon_p
#  ConvMamba vs Mamba (Tier-B)       12          0.0045       8   0.2527      0.1294
# Mamba all vs base40 (Tier-A)       12          0.0841      11   0.0014      0.0024
#                Mamba vs TLOB       12         -0.0738       0   0.0000      0.0005
#            ConvMamba vs TLOB       12         -0.0692       0   0.0000      0.0005
#
# (positive mean_delta => first model better; p<0.05 => difference unlikely by chance)
#    ^ s3://lob-capstone-data/experiments/tier_c/results/tier_c_significance.csv

# %% [markdown]
# ## 10. Per-sample paired bootstrap + McNemar (strongest evidence)
# Across-seed tests have few points. Here we take a representative cell (**NIFTY, k=100, seed 0**), reload the
# saved checkpoints from S3, recompute test predictions, and compare models *on the same test instances*:
# a paired bootstrap on the weighted-$F_1$ difference (resampling test rows) and McNemar's test on per-sample
# correctness. These have thousands of points, so they detect smaller real differences.

# %%
import numpy as np, pathlib, torch
from scipy import stats as ss
from sklearn.metrics import f1_score
from nse_dataset import load_nse
from models import build_model
from train import load_checkpoint, DEVICE
from runner import collect_preds, spec_tag
from nbenv import s3_client, s3_pull_area

EVAL_SYMBOL, EVAL_H, EVAL_SEED = "NIFTY", 100, 0
_cache = {}
def _testset(symbol, horizon, fs):
    k = (symbol, horizon, fs)
    if k not in _cache:
        tr, vl, te = load_nse(symbol=symbol, horizon=horizon, seq_len=100,
                              feature_set=fs, label_scheme="A", data_dir=DATA_DIR_NSE)
        _cache[k] = (tr, te)
    return _cache[k]

def preds_for(model, fs):
    tr, te = _testset(EVAL_SYMBOL, EVAL_H, fs)
    n_features = tr[0][0].shape[-1]
    net = build_model(model, seq_len=100, n_features=n_features)
    tag = spec_tag({"model": model, "symbol": EVAL_SYMBOL, "feature_set": fs,
                    "horizon": EVAL_H, "label_scheme": "A", "seed": EVAL_SEED})
    ckpt = pathlib.Path(f"checkpoints/tierc/{tag}.pt")
    if not ckpt.exists():
        s3_pull_area(s3_client(), ckpt, AREA)
    net = load_checkpoint(net, str(ckpt))
    yp, yt = collect_preds(net, te)
    return yt, yp

def paired_bootstrap_wf1(yt, pa, pb, n_boot=2000, seed=0):
    rng = np.random.default_rng(seed); n = len(yt)
    d0 = f1_score(yt, pa, average="weighted", zero_division=0) - \
         f1_score(yt, pb, average="weighted", zero_division=0)
    diffs = np.empty(n_boot)
    for i in range(n_boot):
        idx = rng.integers(0, n, n)
        diffs[i] = f1_score(yt[idx], pa[idx], average="weighted", zero_division=0) - \
                   f1_score(yt[idx], pb[idx], average="weighted", zero_division=0)
    lo, hi = np.percentile(diffs, [2.5, 97.5])
    return d0, lo, hi, float((diffs > 0).mean())

def mcnemar(yt, pa, pb):
    ca, cb = (pa == yt), (pb == yt)
    b = int((ca & ~cb).sum()); c = int((~ca & cb).sum())     # discordant
    # exact McNemar via binomial on discordant pairs
    p = ss.binomtest(min(b, c), b + c, 0.5).pvalue if (b + c) else 1.0
    return b, c, p

PAIRS = [("convmambalob", "all", "mambalob", "all"),
         ("mambalob", "all", "mambalob", "base40"),
         ("mambalob", "all", "tlob", "all")]
print(f"Per-sample comparison at {EVAL_SYMBOL} k={EVAL_H} seed={EVAL_SEED}\n" + "=" * 60)
for ma, fa, mb, fb in PAIRS:
    yt_a, pa = preds_for(ma, fa)
    yt_b, pb = preds_for(mb, fb)
    assert np.array_equal(yt_a, yt_b), "label mismatch -> test sets differ"
    yt = yt_a
    d0, lo, hi, frac = paired_bootstrap_wf1(yt, pa, pb)
    b, c, mp = mcnemar(yt, pa, pb)
    sig = "SIGNIF" if (lo > 0 or hi < 0) else "n.s."
    print(f"{ma}/{fa}  vs  {mb}/{fb}  (n={len(yt)})")
    print(f"   ΔwF1={d0:+.4f}  95%CI=[{lo:+.4f},{hi:+.4f}]  P(Δ>0)={frac:.2f}  [{sig}]")
    print(f"   McNemar: A-only-correct={b}, B-only-correct={c}, p={mp:.4g}\n")
# Out:
# Using device: cuda
# Per-sample comparison at NIFTY k=100 seed=0
# ============================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
# MambaLOB: using mamba-ssm CUDA kernel.
# convmambalob/all  vs  mambalob/all  (n=341214)
#    ΔwF1=+0.0154  95%CI=[+0.0140,+0.0167]  P(Δ>0)=1.00  [SIGNIF]
#    McNemar: A-only-correct=34621, B-only-correct=29577, p=3.097e-88
#
# MambaLOB: using mamba-ssm CUDA kernel.
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: base40  (F=40)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# MambaLOB: using mamba-ssm CUDA kernel.
# mambalob/all  vs  mambalob/base40  (n=341214)
#    ΔwF1=+0.0426  95%CI=[+0.0408,+0.0444]  P(Δ>0)=1.00  [SIGNIF]
#    McNemar: A-only-correct=59605, B-only-correct=47055, p=0
#
# MambaLOB: using mamba-ssm CUDA kernel.
# mambalob/all  vs  tlob/all  (n=341214)
#    ΔwF1=-0.0867  95%CI=[-0.0882,-0.0851]  P(Δ>0)=0.00  [SIGNIF]
#    McNemar: A-only-correct=29672, B-only-correct=60928, p=0

# %% [markdown]
# ## 11. Probability calibration (temperature scaling)
# A classifier can be accurate but over-confident. We fit a single temperature $T$ on the validation logits
# (minimising NLL) and report **Expected Calibration Error (ECE)** before/after on the test set, for the
# proposed model. Lower ECE => probabilities are more trustworthy for the cost-aware backtest.

# %%
import numpy as np, torch, torch.nn.functional as F
from nse_dataset import load_nse
from models import build_model
from train import load_checkpoint, DEVICE
from fi2010_dataset import make_loader
from runner import spec_tag
from nbenv import s3_client, s3_pull_area
import pathlib

CAL_MODEL, CAL_FS, CAL_SYM, CAL_H, CAL_SEED = "convmambalob", "all", "NIFTY", 100, 0

def logits_labels(net, ds):
    net = net.to(DEVICE).eval(); L, Y = [], []
    with torch.no_grad():
        for X, y in make_loader(ds, batch_size=256, shuffle=False):
            L.append(net(X.to(DEVICE)).cpu()); Y.append(y)
    return torch.cat(L), torch.cat(Y)

def ece(probs, labels, n_bins=15):
    conf, pred = probs.max(1)
    acc = (pred == labels).float()
    bins = torch.linspace(0, 1, n_bins + 1)
    e = 0.0
    for i in range(n_bins):
        m = (conf > bins[i]) & (conf <= bins[i + 1])
        if m.any():
            e += m.float().mean() * (acc[m].mean() - conf[m].mean()).abs()
    return float(e)

tr, vl, te = load_nse(symbol=CAL_SYM, horizon=CAL_H, seq_len=100, feature_set=CAL_FS,
                      label_scheme="A", data_dir=DATA_DIR_NSE)
net = build_model(CAL_MODEL, seq_len=100, n_features=tr[0][0].shape[-1])
tag = spec_tag({"model": CAL_MODEL, "symbol": CAL_SYM, "feature_set": CAL_FS,
                "horizon": CAL_H, "label_scheme": "A", "seed": CAL_SEED})
ckpt = pathlib.Path(f"checkpoints/tierc/{tag}.pt")
if not ckpt.exists():
    s3_pull_area(s3_client(), ckpt, AREA)
net = load_checkpoint(net, str(ckpt))

val_logits, val_y = logits_labels(net, vl)
test_logits, test_y = logits_labels(net, te)

# fit temperature on validation NLL
T = torch.nn.Parameter(torch.ones(1))
opt = torch.optim.LBFGS([T], lr=0.01, max_iter=100)
def _closure():
    opt.zero_grad()
    loss = F.cross_entropy(val_logits / T.clamp(min=1e-2), val_y)
    loss.backward(); return loss
opt.step(_closure)
Tval = float(T.detach().clamp(min=1e-2))

ece_before = ece(F.softmax(test_logits, 1), test_y)
ece_after = ece(F.softmax(test_logits / Tval, 1), test_y)
print(f"{CAL_MODEL}/{CAL_FS} {CAL_SYM} k={CAL_H} seed={CAL_SEED}")
print(f"  fitted temperature T = {Tval:.3f}  ({'over' if Tval>1 else 'under'}-confident before)")
print(f"  ECE before = {ece_before:.4f}")
print(f"  ECE after  = {ece_after:.4f}   ({100*(ece_before-ece_after)/max(ece_before,1e-9):+.1f}% change)")
# Out:
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
# convmambalob/all NIFTY k=100 seed=0
#   fitted temperature T = 1.000  (under-confident before)
#   ECE before = 0.0405
#   ECE after  = 0.0405   (+0.0% change)

# %% [markdown]
# ## 12. Tier-C summary
#
# Read off, for the report:
# - **Tier-A claim** (microstructure features help): see the `Mamba all vs base40` row in §9 (across-seed) and §10
#   (per-sample) — significant if CI excludes 0 / p<0.05.
# - **Tier-B claim** (ConvMambaLOB > base): `ConvMamba vs Mamba` rows.
# - **Gap to TLOB**: `* vs TLOB` rows quantify it with uncertainty (expected: TLOB ahead, but report the CI).
# - **Calibration**: temperature + ECE improvement (§11) — needed before trusting predicted probabilities in the
#   cost-aware backtest.
#
# All summary CSVs (`tier_c_summary_*`, `tier_c_significance`) are on S3 under `experiments/tier_c/results/`.
