# %% [markdown]
# # Tier-B — Improved MambaLOB architectures (headline novelty)
#
# Phase-2 Tier B. The base MambaLOB is *causal* (left→right scan) and feature-flat. Here we test two
# architectural improvements, asking the headline question:
#
# > **Can a better-designed Mamba match or beat TLOB (the transformer SOTA) at lower compute?**
#
# Variants (all in `modeling/models.py`):
# - **`bimambalob`** — bidirectional Mamba (`_BiMamba`): each block reads the look-back window forwards *and*
#   backwards and averages, so every position sees its full local neighbourhood (still O(L), 2× constant).
# - **`convmambalob`** — DeepLOB's Conv+Inception *spatial* front-end → Mamba *temporal* core (replaces DeepLOB's
#   sequential LSTM with a selective SSM). Hybrid: CNN inductive bias + O(L) long-range temporal modelling.
# - **`biconvmambalob`** — both improvements combined.
# - Baselines for context: **`mambalob`** (our base) and **`tlob`** (transformer SOTA target).
#
# All run on the **best feature set from Tier A (`all`, 66 features)** — see Section 3.3 of the report.
# Reuses the dual-GPU sharded runner (each shard pinned to one T4 via `CUDA_VISIBLE_DEVICES`).
#
# Setup: enable **GPU T4 x2**; secrets `GH_PAT`, `AWS_ACCESS_KEY_ID`, `AWS_SECRET_ACCESS_KEY`.
# Clean S3 layout: `experiments/architecture/{results,checkpoints,figures}/`.

# %% [markdown]
# ## 1. Runtime check (expect 2 GPUs)

# %%
import torch, platform
print("Python:", platform.python_version(), "| Torch:", torch.__version__)
n = torch.cuda.device_count()
print(f"GPUs visible: {n}")
for i in range(n):
    print(f"  cuda:{i} = {torch.cuda.get_device_name(i)}")
assert n >= 1, "Enable GPU. For 2x speedup choose 'GPU T4 x2'."
if n < 2:
    print("Only 1 GPU -> will run a single shard (still works, no speedup).")
# Out:
# Python: 3.12.13 | Torch: 2.10.0+cu128
# GPUs visible: 2
#   cuda:0 = Tesla T4
#   cuda:1 = Tesla T4

# %% [markdown]
# ## 2. Get the project code (GH_PAT secret)

# %%
import sys, subprocess, pathlib
REPO_URL = "https://github.com/rajjoseph48/nse-lob-capstone.git"
REPO_DIR = "nse-lob-capstone"
def _get_secret(name):
    try:
        from kaggle_secrets import UserSecretsClient
        v = UserSecretsClient().get_secret(name)
        if v:
            return v
    except Exception:
        pass
    try:
        from google.colab import userdata
        v = userdata.get(name)
        if v:
            return v
    except Exception:
        pass
    import os
    return os.environ.get(name, "")
GITHUB_TOKEN = _get_secret("GH_PAT")
def add_modeling(base):
    base = pathlib.Path(base)
    for cand in (base / "modeling", base):
        if (cand / "models.py").exists():
            sys.path.insert(0, str(cand.resolve()))
            return str(cand.resolve())
    return None
MODELING_DIR = None
for c in (".", REPO_DIR, "/kaggle/working/" + REPO_DIR, "/content/" + REPO_DIR):
    MODELING_DIR = add_modeling(c)
    if MODELING_DIR:
        break
if not MODELING_DIR:
    url = REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@") if GITHUB_TOKEN else REPO_URL
    subprocess.run(["git", "clone", "--depth", "1", url], check=True)
    MODELING_DIR = add_modeling(REPO_DIR)
print("modeling/ dir:", MODELING_DIR)
# Out:
# modeling/ dir: /kaggle/working/nse-lob-capstone/modeling

# %% [markdown]
# ## 3. Install deps (Mamba kernel + boto3)

# %%
import subprocess, sys
def pipq(*pkgs): subprocess.run([sys.executable, "-m", "pip", "install", "-q", *pkgs], check=False)
pipq("boto3")
pipq("ninja", "packaging", "setuptools", "wheel")
pipq("--no-build-isolation", "causal-conv1d")
pipq("--no-build-isolation", "mamba-ssm")
try:
    import mamba_ssm
    print("install step done | mamba-ssm", mamba_ssm.__version__)
except Exception as e:
    print("install step done | mamba-ssm NOT importable -> pure-PyTorch fallback:", repr(e))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 74.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 MB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 46.7 MB/s eta 0:00:00
# install step done | mamba-ssm 2.3.2.post1

# %% [markdown]
# ## 4. Download NSE data from S3 (shared by both shards)

# %%
import os, boto3, pathlib
os.environ["AWS_ACCESS_KEY_ID"] = _get_secret("AWS_ACCESS_KEY_ID")
os.environ["AWS_SECRET_ACCESS_KEY"] = _get_secret("AWS_SECRET_ACCESS_KEY")
BUCKET, PREFIX, REGION = "lob-capstone-data", "lob-data/dhan/", "ap-south-2"
DATA_DIR_NSE = "nse_data/dhan"; pathlib.Path(DATA_DIR_NSE).mkdir(parents=True, exist_ok=True)
s3 = boto3.client("s3", region_name=REGION)
n = 0
for o in s3.list_objects_v2(Bucket=BUCKET, Prefix=PREFIX).get("Contents", []):
    if o["Size"] == 0:
        continue
    dst = os.path.join(DATA_DIR_NSE, o["Key"].split("/")[-1])
    if not os.path.exists(dst):
        s3.download_file(BUCKET, o["Key"], dst)
    n += 1
print(f"{n} parquet files in {DATA_DIR_NSE}")
# Out:
# 27 parquet files in nse_data/dhan

# %% [markdown]
# ## 5. Build the Tier-B run-list + resume
# `GRID` is the experiment list. We compare the improved Mamba variants against the base MambaLOB and the
# TLOB SOTA target, all on the `all` feature set, NIFTY + BANKNIFTY, horizons 10 & 100. We pull merged
# results from S3 and keep only not-yet-done specs.

# %%
import json, pathlib, pandas as pd
from nbenv import s3_client, s3_pull_area

AREA = "architecture"
MERGED = pathlib.Path("results/architecture.csv")
FEATURE_SET = "all"                                  # best from Tier A
MODELS = ["mambalob", "bimambalob", "convmambalob", "biconvmambalob", "tlob"]

GRID = []
for sym in ["NIFTY", "BANKNIFTY"]:
    for model in MODELS:
        for h in [10, 100]:
            GRID.append({"model": model, "symbol": sym, "feature_set": FEATURE_SET,
                         "horizon": h, "label_scheme": "A", "seed": 0})

_s3 = s3_client(); s3_pull_area(_s3, MERGED, AREA)
done = set()
if MERGED.exists():
    d = pd.read_csv(MERGED)
    done = {(r.model, r.symbol, r.feature_set, int(r.horizon), r.label_scheme, int(r.seed))
            for r in d.itertuples()}
def _key(s):
    return (s["model"], s["symbol"], s["feature_set"], int(s["horizon"]), s["label_scheme"], int(s["seed"]))
todo = [s for s in GRID if _key(s) not in done]
pathlib.Path("runlist.json").write_text(json.dumps(todo))
print(f"grid={len(GRID)} | done={len(done)} | to run this session={len(todo)}")
todo
# Out:
#    pulled s3://lob-capstone-data/experiments/architecture/results/architecture.csv (resuming)
# grid=20 | done=14 | to run this session=6
# [{'model': 'mambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'bimambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'convmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'biconvmambalob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'tlob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 10,
#   'label_scheme': 'A',
#   'seed': 0},
#  {'model': 'tlob',
#   'symbol': 'BANKNIFTY',
#   'feature_set': 'all',
#   'horizon': 100,
#   'label_scheme': 'A',
#   'seed': 0}]

# %% [markdown]
# ## 6. Launch one shard per GPU (concurrent) and stream logs
# Each shard is a subprocess pinned to one GPU via `CUDA_VISIBLE_DEVICES`. We tail both logs until done.

# %%
import os, sys, subprocess, time, torch

n_gpus = torch.cuda.device_count()
nshards = max(1, n_gpus)
RUN_SHARD = f"{MODELING_DIR}/run_shard.py"
pathlib.Path("results").mkdir(exist_ok=True)

procs = []
for i in range(nshards):
    env = dict(os.environ); env["CUDA_VISIBLE_DEVICES"] = str(i)
    logf = f"shard{i}.log"; fh = open(logf, "w")
    cmd = [sys.executable, RUN_SHARD, "--runlist", "runlist.json", "--shard", str(i),
           "--nshards", str(nshards), "--data-dir", DATA_DIR_NSE, "--out", f"results/shard{i}.csv",
           "--ckpt-dir", "checkpoints/arch", "--area", "architecture", "--epochs", "20"]
    procs.append([subprocess.Popen(cmd, env=env, stdout=fh, stderr=subprocess.STDOUT), fh, logf, 0])
    print(f"launched shard {i} on CUDA_VISIBLE_DEVICES={i}")

while any(p[0].poll() is None for p in procs):
    for p in procs:
        with open(p[2]) as r:
            r.seek(p[3]); chunk = r.read(); p[3] = r.tell()
        if chunk:
            print(chunk, end="")
    time.sleep(10)
for p in procs:                                        # final flush
    p[1].close()
    with open(p[2]) as r:
        r.seek(p[3]); print(r.read(), end="")
print("\nexit codes:", [p[0].poll() for p in procs])
# Out:
# launched shard 0 on CUDA_VISIBLE_DEVICES=0
# launched shard 1 on CUDA_VISIBLE_DEVICES=1
# Using device: cuda
# [shard 1/2] device=cuda | CUDA_VISIBLE_DEVICES=1 | 10 runs
#
# [shard 1] run 1/10: {'model': 'mambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   mambalob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 5.9405 | val_loss 0.9491 | val_f1 0.6630 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/mambalob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/mambalob_NIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6430 mF1=0.4728 (F=66, 294s)
#
# [shard 1] run 2/10: {'model': 'bimambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   bimambalob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 2.0471 | val_loss 0.9725 | val_f1 0.6535 ← best
#   epoch   5 | train_loss 67.4287 | val_loss 1.0062 | val_f1 0.6374
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/bimambalob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/bimambalob_NIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6230 mF1=0.4644 (F=66, 705s)
#
# [shard 1] run 3/10: {'model': 'convmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 0.9625 | val_loss 0.9575 | val_f1 0.6623 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/convmambalob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/convmambalob_NIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6303 mF1=0.4762 (F=66, 1448s)
#
# [shard 1] run 4/10: {'model': 'biconvmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   biconvmambalob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 1.2378 | val_loss 0.9672 | val_f1 0.6263 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/biconvmambalob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/biconvmambalob_NIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6243 mF1=0.4767 (F=66, 1728s)
#
# [shard 1] run 5/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_NIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 766,559  val: 85,074  test: 341,214
#     train labels: Down:48.2%  Stat:5.0%  Up:46.8%  (n=766,559)
#     val   labels: Down:45.2%  Stat:3.8%  Up:50.9%  (n=85,074)Using device: cuda
# [shard 0/2] device=cuda | CUDA_VISIBLE_DEVICES=0 | 10 runs
#
# [shard 0] run 1/10: {'model': 'mambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   mambalob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 2.4380 | val_loss 0.9939 | val_f1 0.5305 ← best
#   epoch   5 | train_loss 8.7804 | val_loss 0.9599 | val_f1 0.5612 ← best
#   epoch  10 | train_loss 852.6272 | val_loss 0.9625 | val_f1 0.5619
#   Early stop at epoch 10 (best epoch 7).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/mambalob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/mambalob_NIFTY_all_h10_s0_metrics.json
#   -> wF1=0.5423 mF1=0.5209 (F=66, 738s)
#
# [shard 0] run 2/10: {'model': 'bimambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   bimambalob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 631.0999 | val_loss 0.9877 | val_f1 0.5357 ← best
#   epoch   5 | train_loss 5.5736 | val_loss 0.9596 | val_f1 0.5601 ← best
#   epoch  10 | train_loss 3821.5687 | val_loss 0.9709 | val_f1 0.5638
#   Early stop at epoch 11 (best epoch 8).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/bimambalob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/bimambalob_NIFTY_all_h10_s0_metrics.json
#   -> wF1=0.5286 mF1=0.5033 (F=66, 1523s)
#
# [shard 0] run 3/10: {'model': 'convmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 0.9885 | val_loss 0.9672 | val_f1 0.5537 ← best
#   epoch   5 | train_loss 0.8734 | val_loss 1.0277 | val_f1 0.5428
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/convmambalob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/convmambalob_NIFTY_all_h10_s0_metrics.json
#   -> wF1=0.5471 mF1=0.5273 (F=66, 2246s)
#
# [shard 0] run 4/10: {'model': 'biconvmambalob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   biconvmambalob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 1.2336 | val_loss 0.9709 | val_f1 0.5489 ← best
#   epoch   5 | train_loss 2.2528 | val_loss 1.0005 | val_f1 0.5485
#   Early stop at epoch 7 (best epoch 4).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/biconvmambalob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/biconvmambalob_NIFTY_all_h10_s0_metrics.json
#   -> wF1=0.5404 mF1=0.5212 (F=66, 3022s)
#
# [shard 0] run 5/10: {'model': 'tlob', 'symbol': 'NIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_NIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=NIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#     20260514 NIFTY: dropped 1 outlier rows
#     20260515 NIFTY: dropped 1 outlier rows
#     20260522 NIFTY: dropped 1 outlier rows
#     20260602 NIFTY: dropped 1 outlier rows
#     20260603 NIFTY: dropped 1 outlier rows
#     20260608 NIFTY: dropped 2 outlier rows
#     20260609 NIFTY: dropped 1 outlier rows
#     20260612 NIFTY: dropped 1 outlier rows
#     test  labels: Down:47.1%  Stat:5.5%  Up:47.4%  (n=341,214)
#   epoch   1 | train_loss 0.8824 | val_loss 0.8711 | val_f1 0.6798 ← best
#   epoch   5 | train_loss 0.6295 | val_loss 1.0854 | val_f1 0.6968
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/tlob_NIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/tlob_NIFTY_all_h100_s0_metrics.json
#   -> wF1=0.7138 mF1=0.5375 (F=66, 3113s)
#
# [shard 1] run 6/10: {'model': 'mambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   mambalob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 3545671.7981 | val_loss 0.9740 | val_f1 0.6059 ← best
#   epoch   5 | train_loss 100414126.7377 | val_loss 1.1399 | val_f1 0.6567
#   Early stop at epoch 7 (best epoch 4).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/mambalob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/mambalob_BANKNIFTY_all_h100_s0_metrics.json
#   -> wF1=0.5889 mF1=0.4364 (F=66, 523s)
#
# [shard 1] run 7/10: {'model': 'bimambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   bimambalob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 350986170.4617 | val_loss 0.9649 | val_f1 0.6569 ← best
#   epoch   5 | train_loss 19909682.5762 | val_loss 5.4949 | val_f1 0.6502
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/bimambalob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/bimambalob_BANKNIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6258 mF1=0.4630 (F=66, 839s)
#
# [shard 1] run 8/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 27628.5820 | val_loss 0.9352 | val_f1 0.6488 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/convmambalob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/convmambalob_BANKNIFTY_all_h100_s0_metrics.json
#   -> wF1=0.6113 mF1=0.4560 (F=66, 1471s)
#
# [shard 1] run 9/10: {'model': 'biconvmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   biconvmambalob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 189161.1015 | val_loss 0.9494 | val_f1 0.6502 ← best
#   Early stop at epoch 4 (best epoch 1).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/biconvmambalob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/biconvmambalob_BANKNIFTY_all_h100_s0_metrics.json
#   -> wF1=0.5701 mF1=0.4252 (F=66, 1706s)
#
# [shard 1] run 10/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 100, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_BANKNIFTY_all_h100_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k100 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 762,890  val: 84,666  test: 338,375
#     train labels: Down:48.7%  Stat:3.9%  Up:47.5%  (n=762,890)
#     val   labels: Down:45.2%  Stat:3.4%  Up:51.4%  (n=84,666)
#     test  labels: Down:47.2%  Stat:4.0%  Up:48.8%  (n=338,375)
#   epoch   1 | train_loss 0.8767 | val_loss 0.8788 | val_f1 0.6994 ← best
#   epoch   5 | train_loss 0.5621 | val_loss 1.1846 | val_f1 0.7185
#   Early stop at epoch 5 (best epoch 2).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/tlob_BANKNIFTY_all_h100_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/tlob_BANKNIFTY_all_h100_s0_metrics.json
#   -> wF1=0.7121 mF1=0.5315 (F=66, 3079s)
# [shard 1] done.
#
#   Contracts stitched: ['NIFTY-JUN-FUT', 'NIFTY-MAY-FUT']
#   Train rows: 854,717  Test rows: 342,408
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 767,729  val: 85,254  test: 341,754
#     train labels: Down:39.5%  Stat:21.9%  Up:38.6%  (n=767,729)
#     val   labels: Down:39.1%  Stat:19.1%  Up:41.8%  (n=85,254)
#     test  labels: Down:38.0%  Stat:23.8%  Up:38.3%  (n=341,754)
#   epoch   1 | train_loss 0.9186 | val_loss 0.8890 | val_f1 0.6130 ← best
#   epoch   5 | train_loss 0.8487 | val_loss 0.8736 | val_f1 0.6236 ← best
#   Early stop at epoch 8 (best epoch 5).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/tlob_NIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/tlob_NIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6052 mF1=0.5845 (F=66, 5007s)
#
# [shard 0] run 6/10: {'model': 'mambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   mambalob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 25995878.1708 | val_loss 0.9530 | val_f1 0.5677 ← best
#   epoch   5 | train_loss 6372669.1053 | val_loss 0.8702 | val_f1 0.6220 ← best
#   Early stop at epoch 9 (best epoch 6).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/mambalob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/mambalob_BANKNIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6064 mF1=0.6011 (F=66, 656s)
#
# [shard 0] run 7/10: {'model': 'bimambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   bimambalob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# MambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 45258179.3752 | val_loss 1.2016 | val_f1 0.5718 ← best
#   epoch   5 | train_loss 187129340.8977 | val_loss 1.2570 | val_f1 0.6207 ← best
#   epoch  10 | train_loss 134760147.7817 | val_loss 0.9184 | val_f1 0.6184
#   Early stop at epoch 10 (best epoch 7).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/bimambalob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/bimambalob_BANKNIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6097 mF1=0.6051 (F=66, 1372s)
#
# [shard 0] run 8/10: {'model': 'convmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   convmambalob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 3.6566 | val_loss 0.8743 | val_f1 0.6153 ← best
#   epoch   5 | train_loss 3498.6429 | val_loss 0.9212 | val_f1 0.6112
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/convmambalob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/convmambalob_BANKNIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6192 mF1=0.6139 (F=66, 2235s)
#
# [shard 0] run 9/10: {'model': 'biconvmambalob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   biconvmambalob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
# ConvMambaLOB: using mamba-ssm CUDA kernel.
#   epoch   1 | train_loss 13.6607 | val_loss 0.8693 | val_f1 0.6129 ← best
#   epoch   5 | train_loss 5402.4202 | val_loss 0.9195 | val_f1 0.6063
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/biconvmambalob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/biconvmambalob_BANKNIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6136 mF1=0.6094 (F=66, 2575s)
#
# [shard 0] run 10/10: {'model': 'tlob', 'symbol': 'BANKNIFTY', 'feature_set': 'all', 'horizon': 10, 'label_scheme': 'A', 'seed': 0}
# ============================================================================
#   tlob_BANKNIFTY_all_h10_s0  | device=cuda
#  ============================================================================
#
# Loading NSE | root=BANKNIFTY (front-month) | horizon=k10 | seq_len=100 | alpha=1e-05
#   Train dates (15): 20260512..20260604
#   Test  dates (6): ['20260605', '20260608', '20260609', '20260610', '20260611', '20260612']
#   Contracts stitched: ['BANKNIFTY-JUN-FUT', 'BANKNIFTY-MAY-FUT']
#   Train rows: 850,640  Test rows: 339,569
#   Feature set: all  (F=66)
#   Scheme A (fixed alpha): threshold=1.00e-05
#   Splits   train: 764,060  val: 84,846  test: 338,915
#     train labels: Down:37.1%  Stat:26.2%  Up:36.7%  (n=764,060)
#     val   labels: Down:38.2%  Stat:21.2%  Up:40.6%  (n=84,846)
#     test  labels: Down:35.6%  Stat:26.5%  Up:37.9%  (n=338,915)
#   epoch   1 | train_loss 0.8453 | val_loss 0.8349 | val_f1 0.6415 ← best
#   epoch   5 | train_loss 0.7430 | val_loss 0.8556 | val_f1 0.6392
#   Early stop at epoch 6 (best epoch 3).
#    ^ s3://lob-capstone-data/experiments/architecture/checkpoints/tlob_BANKNIFTY_all_h10_s0.pt
#    ^ s3://lob-capstone-data/experiments/architecture/results/tlob_BANKNIFTY_all_h10_s0_metrics.json
#   -> wF1=0.6319 mF1=0.6264 (F=66, 3715s)
# [shard 0] done.
#
# exit codes: [0, 0]

# %% [markdown]
# ## 7. Merge shard CSVs + push to S3

# %%
import glob, pandas as pd
from nbenv import s3_client, s3_put_area
keys = ["model", "symbol", "feature_set", "horizon", "label_scheme", "seed"]
frames = [pd.read_csv(MERGED)] if MERGED.exists() else []
frames += [pd.read_csv(f) for f in glob.glob("results/shard*.csv")]
alldf = pd.concat(frames, ignore_index=True).drop_duplicates(subset=keys, keep="last") if frames else pd.DataFrame()
alldf.to_csv(MERGED, index=False)
s3_put_area(s3_client(), MERGED, AREA)
print(f"merged {len(alldf)} rows -> {MERGED}  (s3: experiments/{AREA}/results/)")
alldf.sort_values(keys)
# Out:
#    ^ s3://lob-capstone-data/experiments/architecture/results/architecture.csv
# merged 20 rows -> results/architecture.csv  (s3: experiments/architecture/results/)
#              model     symbol feature_set label_scheme  horizon  seed  \
# 46  biconvmambalob  BANKNIFTY         all            A       10     0
# 31  biconvmambalob  BANKNIFTY         all            A      100     0
# 41  biconvmambalob      NIFTY         all            A       10     0
# 26  biconvmambalob      NIFTY         all            A      100     0
# 44      bimambalob  BANKNIFTY         all            A       10     0
# 29      bimambalob  BANKNIFTY         all            A      100     0
# 39      bimambalob      NIFTY         all            A       10     0
# 24      bimambalob      NIFTY         all            A      100     0
# 45    convmambalob  BANKNIFTY         all            A       10     0
# 30    convmambalob  BANKNIFTY         all            A      100     0
# 40    convmambalob      NIFTY         all            A       10     0
# 25    convmambalob      NIFTY         all            A      100     0
# 43        mambalob  BANKNIFTY         all            A       10     0
# 28        mambalob  BANKNIFTY         all            A      100     0
# 38        mambalob      NIFTY         all            A       10     0
# 23        mambalob      NIFTY         all            A      100     0
# 47            tlob  BANKNIFTY         all            A       10     0
# 32            tlob  BANKNIFTY         all            A      100     0
# 42            tlob      NIFTY         all            A       10     0
# 27            tlob      NIFTY         all            A      100     0
#
#     n_features  n_params  test_accuracy  test_macro_f1  test_weighted_f1  \
# 46          66    209015         0.6112         0.6094            0.6136
# 31          66    209015         0.5274         0.4252            0.5701
# 41          66    209015         0.5400         0.5212            0.5404
# 26          66    209015         0.5821         0.4767            0.6243
# 44          66    135235         0.6074         0.6051            0.6097
# 29          66    135235         0.5999         0.4630            0.6258
# 39          66    135235         0.5376         0.5033            0.5286
# 24          66    135235         0.6238         0.4644            0.6230
# 45          66    143735         0.6174         0.6139            0.6192
# 30          66    143735         0.5517         0.4560            0.6113
# 40          66    143735         0.5472         0.5273            0.5471
# 25          66    143735         0.6116         0.4762            0.6303
# 43          66     69955         0.6044         0.6011            0.6064
# 28          66     69955         0.5667         0.4364            0.5889
# 38          66     69955         0.5439         0.5209            0.5423
# 23          66     69955         0.6474         0.4728            0.6430
# 47          66   1803728         0.6262         0.6264            0.6319
# 32          66   1803728         0.6812         0.5315            0.7121
# 42          66   1803728         0.5988         0.5845            0.6052
# 27          66   1803728         0.7037         0.5375            0.7138
#
#     test_mcc  train_time_s  best_epoch  epochs_run  best_val_f1  \
# 46    0.4223        2574.6         3.0         6.0       0.6219
# 31    0.2947        1705.5         1.0         4.0       0.6502
# 41    0.2978        3022.3         4.0         7.0       0.5574
# 26    0.3341        1727.8         1.0         4.0       0.6263
# 44    0.4142        1371.6         7.0        10.0       0.6241
# 29    0.3204         839.1         3.0         6.0       0.6625
# 39    0.2850        1522.9         8.0        11.0       0.5658
# 24    0.3323         704.7         2.0         5.0       0.6581
# 45    0.4256        2234.6         3.0         6.0       0.6254
# 30    0.3222        1470.9         1.0         4.0       0.6488
# 40    0.3071        2246.5         3.0         6.0       0.5621
# 25    0.3416        1448.3         1.0         4.0       0.6623
# 43    0.4084         656.1         6.0         9.0       0.6257
# 28    0.2699         522.8         4.0         7.0       0.6571
# 38    0.2995         737.9         7.0        10.0       0.5637
# 23    0.3527         294.5         1.0         4.0       0.6630
# 47    0.4561        3715.1         3.0         6.0       0.6437
# 32    0.4590        3079.1         2.0         5.0       0.7269
# 42    0.3958        5006.9         5.0         8.0       0.6236
# 27    0.4764        3113.3         2.0         5.0       0.7179
#
#     baseline_majority_wf1  baseline_stat_wf1  baseline_random_wf1
# 46                 0.1872             0.1107               0.3409
# 31                 0.3022             0.0031               0.4630
# 41                 0.2091             0.0912               0.3493
# 26                 0.3017             0.0057               0.4507
# 44                 0.1872             0.1107               0.3409
# 29                 0.3022             0.0031               0.4630
# 39                 0.2091             0.0912               0.3493
# 24                 0.3017             0.0057               0.4507
# 45                 0.1872             0.1107               0.3409
# 30                 0.3022             0.0031               0.4630
# 40                 0.2091             0.0912               0.3493
# 25                 0.3017             0.0057               0.4507
# 43                 0.1872             0.1107               0.3409
# 28                 0.3022             0.0031               0.4630
# 38                 0.2091             0.0912               0.3493
# 23                 0.3017             0.0057               0.4507
# 47                 0.1872             0.1107               0.3409
# 32                 0.3022             0.0031               0.4630
# 42                 0.2091             0.0912               0.3493
# 27                 0.3017             0.0057               0.4507

# %% [markdown]
# ## 8. Findings — do the improved architectures beat TLOB at lower compute?
# The headline claim is **quality at lower cost**: we read weighted/macro-F1 *and* parameter count and
# train time together. A Mamba variant that matches TLOB's F1 with fewer params / less time supports
# "we designed a better LOB model".

# %%
import matplotlib.pyplot as plt
res = pd.read_csv(MERGED)
ORDER = ["mambalob", "bimambalob", "convmambalob", "biconvmambalob", "tlob"]

for sym in sorted(res.symbol.unique()):
    sub = res[res.symbol == sym]
    print("=" * 70, f"\n{sym}\n" + "=" * 70)
    piv = sub.pivot_table(index="model", columns="horizon", values="test_weighted_f1").reindex(ORDER)
    print("weighted-F1 by model x horizon:")
    print(piv.round(4).to_string())
    pm = sub.pivot_table(index="model", columns="horizon", values="test_macro_f1").reindex(ORDER)
    print("\nmacro-F1 by model x horizon:")
    print(pm.round(4).to_string())

# Efficiency: params & train time (model-level, averaged over symbol/horizon)
eff = res.groupby("model").agg(
    params=("n_params", "max"),
    avg_train_s=("train_time_s", "mean"),
    avg_wf1=("test_weighted_f1", "mean"),
    avg_mf1=("test_macro_f1", "mean"),
).reindex(ORDER)
print("\nEfficiency vs quality (avg over symbol x horizon):")
print(eff.round({"avg_train_s": 1, "avg_wf1": 4, "avg_mf1": 4}).to_string())

# Quality-vs-compute scatter (the headline plot)
fig, ax = plt.subplots(figsize=(7, 5))
for m in ORDER:
    if m in eff.index and pd.notna(eff.loc[m, "params"]):
        ax.scatter(eff.loc[m, "params"] / 1e3, eff.loc[m, "avg_wf1"], s=90)
        ax.annotate(m, (eff.loc[m, "params"] / 1e3, eff.loc[m, "avg_wf1"]),
                    textcoords="offset points", xytext=(6, 4), fontsize=9)
ax.set(xlabel="parameters (k)", ylabel="avg weighted-F1",
       title="Tier-B: quality vs model size (lower-right = better-and-smaller)")
ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.savefig("results/fig_architecture.png", dpi=150, bbox_inches="tight")
s3_put_area(s3_client(), "results/fig_architecture.png", AREA); plt.show()

# vs-TLOB delta summary
tlob_wf1 = res[res.model == "tlob"].groupby(["symbol", "horizon"]).test_weighted_f1.mean()
print("\nDelta weighted-F1 vs TLOB (positive = our variant beats the transformer):")
for m in ["mambalob", "bimambalob", "convmambalob", "biconvmambalob"]:
    mm = res[res.model == m].groupby(["symbol", "horizon"]).test_weighted_f1.mean()
    d = (mm - tlob_wf1).dropna()
    if len(d):
        print(f"  {m:16s} mean Δ={d.mean():+.4f}  (wins {int((d > 0).sum())}/{len(d)} cells)")
# Out:
# ======================================================================
# BANKNIFTY
# ======================================================================
# weighted-F1 by model x horizon:
# horizon            10      100
# model
# mambalob        0.6064  0.5889
# bimambalob      0.6097  0.6258
# convmambalob    0.6192  0.6113
# biconvmambalob  0.6136  0.5701
# tlob            0.6319  0.7121
#
# macro-F1 by model x horizon:
# horizon            10      100
# model
# mambalob        0.6011  0.4364
# bimambalob      0.6051  0.4630
# convmambalob    0.6139  0.4560
# biconvmambalob  0.6094  0.4252
# tlob            0.6264  0.5315
# ======================================================================
# NIFTY
# ======================================================================
# weighted-F1 by model x horizon:
# horizon            10      100
# model
# mambalob        0.5423  0.6430
# bimambalob      0.5286  0.6230
# convmambalob    0.5471  0.6303
# biconvmambalob  0.5404  0.6243
# tlob            0.6052  0.7138
#
# macro-F1 by model x horizon:
# horizon            10      100
# model
# mambalob        0.5209  0.4728
# bimambalob      0.5033  0.4644
# convmambalob    0.5273  0.4762
# biconvmambalob  0.5212  0.4767
# tlob            0.5845  0.5375
#
# Efficiency vs quality (avg over symbol x horizon):
#                  params  avg_train_s  avg_wf1  avg_mf1
# model
# mambalob          69955        552.8   0.5952   0.5078
# bimambalob       135235       1109.6   0.5968   0.5090
# convmambalob     143735       1850.1   0.6020   0.5184
# biconvmambalob   209015       2257.6   0.5871   0.5081
# tlob            1803728       3728.6   0.6657   0.5700
#    ^ s3://lob-capstone-data/experiments/architecture/figures/fig_architecture.png
# Delta weighted-F1 vs TLOB (positive = our variant beats the transformer):
#   mambalob         mean Δ=-0.0706  (wins 0/4 cells)
#   bimambalob       mean Δ=-0.0690  (wins 0/4 cells)
#   convmambalob     mean Δ=-0.0638  (wins 0/4 cells)
#   biconvmambalob   mean Δ=-0.0786  (wins 0/4 cells)
